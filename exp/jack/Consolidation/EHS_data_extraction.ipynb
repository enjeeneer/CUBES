# %%
import pandas as pd

# %%
general_df = pd.read_stata('/workspaces/CUBES/exp/jack/Data/UKDA-8923-stata/stata/stata13/general_18plus19_eul.dta')
interview_df = pd.read_stata('/workspaces/CUBES/exp/jack/Data/UKDA-8923-stata/stata/stata13/interview_18plus19_eul.dta')
physical_df = pd.read_stata('/workspaces/CUBES/exp/jack/Data/UKDA-8923-stata/stata/stata13/physical_18plus19_eul.dta')

# %%
physical_df.loc[0]
# Out:
# serialanon                   18190000002.0
# dwtypenx                     semi detached
# dwtype8x               semi-detached house
# dwtype3x                 house or bungalow
# housex                   house or bungalow
#                           ...
# cstactcx                       2519.270083
# cststdux                         28.412652
# cststdbx                         35.506716
# cststdcx                         35.506716
# dhcosty       not applicable - decent home
# Name: 0, Length: 72, dtype: object

# %%
physical_df.iloc[10,:].to_excel('/workspaces/CUBES/exp/jack/Data/UKDA-8923-stata/stata/physical_df.xlsx')
