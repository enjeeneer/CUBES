# %%
import pandas as pd
# Out:
# <jemalloc>: MADV_DONTNEED does not work (memset will be used instead)
# <jemalloc>: (This is the expected behaviour if you are running under QEMU)

# %%
#df = pd.read_csv("/workspaces/CUBES/exp/jack/paper/thermostat_experiment/input/occupancy_schedule/schedule_rep_0.sch")
df = pd.read_csv("/workspaces/CUBES/exp/jack/paper/thermostat_experiment/input/occupancy_schedule/occupancy.sch")

# %%
df
# Out:
#                UTC_Time  h43_bathroom_1_upstairs  h28_bathroom_1_upstairs  \
# 0      01/01/2013 00:00                        1                        0
# 1      01/01/2013 00:10                        0                        1
# 2      01/01/2013 00:20                        0                        0
# 3      01/01/2013 00:30                        1                        0
# 4      01/01/2013 00:40                        0                        0
# ...                 ...                      ...                      ...
# 52555  31/12/2013 23:10                        0                        0
# 52556  31/12/2013 23:20                        0                        0
# 52557  31/12/2013 23:30                        0                        0
# 52558  31/12/2013 23:40                        0                        0
# 52559  31/12/2013 23:50                        1                        0
#
#        h42_bathroom_1_upstairs  h45_bathroom_2_upstairs  \
# ...

# %%
percent = df.iloc[:,3].sum()/len(df.iloc[:,1])
percent
# Out:
# 0.344558599695586
