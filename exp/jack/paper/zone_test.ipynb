# %%
from cubes.construct.buildingconfig import load_building_config
from cubes.construct.building import Building
#from cubes.package.utilities import get_rdd_file
#from cubes.package import weather
from cubes.package.envconfig import EnvConfig
#from cubes.package.simple_simulation import prepare_simulation
#from cubes.construct.core import materials_evaluator, windows_evaluator
import os
import pandas as pd
#from geomeppy import IDF
#import pathlib as Path

files_dir = os.getcwd()

bc_file_path = "/workspaces/CUBES/exp/jack/paper/input/building_config.json"
#bc_file_path = "input_c.json"
#bc_file_path = "/workspaces/CUBES/exp/hannes/Leiden-study/01_evaluate_input/evaluation_deterministic_occupancy/case_0/year_2022/rep_0/input_c.json"

materials = pd.read_pickle("/workspaces/CUBES/cubes/materials.pickle")
windows = pd.read_pickle("/workspaces/CUBES/cubes/windows.pickle")

BC = load_building_config(bc_file_path, files_dir=files_dir)
#EC = EnvConfig(files_dir=files_dir)
#building=Building(BC,materials_evaluator(),windows_evaluator())
#building=Building(BC,materials,windows)
#building.build()
#idf = building.get_idf()
# Out:
# <jemalloc>: MADV_DONTNEED does not work (memset will be used instead)
# <jemalloc>: (This is the expected behaviour if you are running under QEMU)
# /workspaces/CUBES/exp/jack/paper/input/schedules.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 22
#      19 materials = pd.read_pickle("/workspaces/CUBES/cubes/materials.pickle")
#      20 windows = pd.read_pickle("/workspaces/CUBES/cubes/windows.pickle")
# ---> 22 BC = load_building_config(bc_file_path, files_dir=files_dir)
#      23 #EC = EnvConfig(files_dir=files_dir)
#      24 #building=Building(BC,materials_evaluator(),windows_evaluator())
#      25 #building=Building(BC,materials,windows)
#      26 #building.build()
#      27 #idf = building.get_idf()
#
# File /workspaces/CUBES/cubes/construct/buildingconfig.py:428, in load_building_config(path_to_datafile, files_dir)
#     424 schedules_path = join(dirname(path_to_datafile), "schedules.json")
#     426 print(schedules_path)
# --> 428 with open(schedules_path, "r", encoding="utf-8") as schedules_file:
#     429     sch_data = json.load(schedules_file)
#     431 for sty, zone_schedule in enumerate(data["occupant_schedule"]):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/CUBES/exp/jack/paper/input/schedules.json'

# %%
idf.save("test.txt")

# %%
#string_test = BC.occupant_schedule_living
#new_list = string_test.split(",")
#changed_list = []
#for entry in new_list:
#
#    if entry[:-1] != "\n":
#        changed_entry = entry[:-4] + "0.25"
#    #else:
#    #    changed_entry = entry
#
#    changed_list.append(changed_entry)
#
#new_sch = ",".join(changed_list)

# %%
idf = prepare_simulation(idf, BC, EC)

idf.run(
        expandobjects=True,
        readvars=True,
        weather="/workspaces/CUBES/cubes/data/weather/Cambridgeshire_CC_2022.epw",
        verbose="q",
    )
# Out:
# [7.2, 7.3, 7.8, 9.0, 11.8, 13.9, 17.3, 19.2, 17.2, 14.2, 12.4, 7.5, 2.0]
# EnergyPlus Completed Successfully.
# EnergyPlus Completed Successfully.

# %%
di = {}
di['hall'] = "x"

# %%
di
# Out:
# {'hall': 'x'}
