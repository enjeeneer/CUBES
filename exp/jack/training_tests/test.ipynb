# %%
from agents.utils import pull_model_from_wandb
from cubes.constants import BASE_DIR
import yaml as yaml
config_path = BASE_DIR / "agents" / "sac" / "config.yaml"
with open(config_path, "rb") as f:
    config = yaml.safe_load(f)

# %%
import torch

baseline_path = BASE_DIR / "agents" / "sac" / "sac-baseline"
no_outdoor_path = BASE_DIR / "agents" / "sac" / "sac-no-outdoors"

baseline_agent = torch.load(baseline_path, map_location=torch.device("cpu"))
no_outdoor_agent = torch.load(no_outdoor_path, map_location=torch.device("cpu"))

# %%
no_outdoor_agent
# Out:
# SoftActorCritic(
#   (actor): AbstractGaussianActor(
#     (trunk): Sequential(
#       (0): Linear(in_features=33, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=8, bias=True)
#     )
#   )
#   (critic): DoubleQCritic(
#     (Q1): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (Q2): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
#   (critic_target): DoubleQCritic(
#     (Q1): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (Q2): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
baseline_agent
# Out:
# SoftActorCritic(
#   (actor): AbstractGaussianActor(
#     (trunk): Sequential(
#       (0): Linear(in_features=33, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=8, bias=True)
#     )
#   )
#   (critic): DoubleQCritic(
#     (Q1): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (Q2): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
#   (critic_target): DoubleQCritic(
#     (Q1): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (Q2): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
no_outdoor_agent
# Out:
# SoftActorCritic(
#   (actor): AbstractGaussianActor(
#     (trunk): Sequential(
#       (0): Linear(in_features=33, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=8, bias=True)
#     )
#   )
#   (critic): DoubleQCritic(
#     (Q1): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (Q2): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
#   (critic_target): DoubleQCritic(
#     (Q1): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (Q2): AbstractCritic(
#       (trunk): Sequential(
#         (0): Linear(in_features=37, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
baseline_agent == no_outdoor_agent
# Out:
# False

# %%
agent = pull_model_from_wandb(
        algorithm="sac",
        wandb_project_id="jack-observations",
        wandb_run_id="we1zd4az",
        wandb_model_id="sac_683280.pickle",
        observation_length=32,
        action_length=4,
        config=config,
    )
# Out:
# 2023-12-01 12:06:39.482 | INFO     | agents.utils:pull_model_from_wandb:203 - Loading model from wandb run: we1zd4az
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     130 try:
# --> 131     result = self._call_fn(*args, **kwargs)
#     132     # Only print resolved attempts once every minute
#
# File /usr/local/lib/python3.9/dist-packages/wandb/apis/public.py:3204, in File.download(self, root, replace, exist_ok)
#    3200         raise ValueError(
#    3201             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#    3202         )
# -> 3204 util.download_file_from_url(path, self.url, Api().api_key)
#    3205 return open(path)
#
# File /usr/local/lib/python3.9/dist-packages/wandb/util.py:1317, in download_file_from_url(dest_path, source_url, api_key)
#    1309 response = requests.get(
#    1310     source_url,
#    1311     auth=auth,
#    (...)
#    1315     timeout=5,
#    1316 )
# -> 1317 response.raise_for_status()
#    1319 if os.sep in dest_path:
#
# File /usr/local/lib/python3.9/dist-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.wandb.ai/files/jjjl4/jack-observations/we1zd4az/sac_683280.pickle
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /workspaces/CUBES/exp/jack/training_tests/test.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> agent = pull_model_from_wandb(
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>         algorithm="sac",
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         wandb_project_id="jack-observations",
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>         wandb_run_id="we1zd4az",
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         wandb_model_id="sac_683280.pickle",
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         observation_length=32,
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         action_length=4,
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>         config=config,
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     )
#
# File /workspaces/CUBES/agents/utils.py:215, in pull_model_from_wandb(algorithm, wandb_project_id, wandb_run_id, wandb_model_id, observation_length, action_length, config)
#     213 else:
#     214     run = api.from_path(f"jjjl4/{wandb_project_id}/runs/{wandb_run_id}")
# --> 215     run.file(wandb_model_id).download(root=save_dir.as_posix(), replace=True)
#     217 # load model
#     218 trained_agent = torch.load(save_path, map_location=torch.device("cpu"))
#
# File /usr/local/lib/python3.9/dist-packages/wandb/apis/normalize.py:73, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      69         raise CommError(message, err.last_exception).with_traceback(
#      70             sys.exc_info()[2]
#      71         )
#      72 except Error as err:
# ---> 73     raise err
#      74 except Exception as err:
#      75     # gql raises server errors with dict's as strings...
#      76     if len(err.args) > 0:
#
# File /usr/local/lib/python3.9/dist-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File /usr/local/lib/python3.9/dist-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File /usr/local/lib/python3.9/dist-packages/wandb/sdk/lib/retry.py:147, in Retry.__call__(self, *args, **kwargs)
#     144     return result
#     145 except self._retryable_exceptions as e:
#     146     # if the secondary check fails, re-raise
# --> 147     retry_timedelta_triggered = check_retry_fn(e)
#     148     if not retry_timedelta_triggered:
#     149         raise
#
# File /usr/local/lib/python3.9/dist-packages/wandb/util.py:906, in no_retry_auth(e)
#     904     raise CommError(f"Permission denied to access {wandb.run.path}")
#     905 else:
# --> 906     raise CommError(
#     907         "It appears that you do not have permission to access the requested resource. "
#     908         "Please reach out to the project owner to grant you access. "
#     909         "If you have the correct permissions, verify that there are no issues with your networking setup."
#     910         f"(Error {e.response.status_code}: {e.response.reason})"
#     911     )
#
# CommError: It appears that you do not have permission to access the requested resource. Please reach out to the project owner to grant you access. If you have the correct permissions, verify that there are no issues with your networking setup.(Error 404: Not Found)

# %%
no_forecast_obs_dict = {'year': 2022, 'month': 2, 'day': 6, 'hour': 23, 'Site Outdoor Air Drybulb Temperature(Environment)': 4.453333333333333, 'Site Outdoor Air Relative Humidity(Environment)': 72.0, 'Site Wind Speed(Environment)': 8.056666666666667, 'Site Wind Direction(Environment)': 296.0, 'Site Diffuse Solar Radiation Rate per Area(Environment)': 0.0, 'Site Direct Solar Radiation Rate per Area(Environment)': 0.0, 'Site Rain Status(Environment)': 0.0, 'Environmental Impact Total CO2 Emissions Carbon Equivalent Mass(Site)': 0.1052799982874532, 'Facility Total Electricity Demand Rate(Whole Building)': 0.0, 'Zone Air Temperature(Living)': 21.04659700518871, 'Zone Air Temperature(Bedroom)': 17.09074094983851, 'Zone Air Temperature(Subfloor)': 9.397616738556167, 'Zone Air Relative Humidity(Living)': 26.20636159551495, 'Zone Air Relative Humidity(Bedroom)': 31.54214801348559, 'Zone Air Relative Humidity(Subfloor)': 51.91854969766736, 'Zone Air CO2 Concentration(Living)': 503.170053263366, 'Zone Air CO2 Concentration(Bedroom)': 420.0000001198778, 'Zone Air CO2 Concentration(Subfloor)': 420.0000000000001, 'Zone People Occupant Count(Living)': 2.0, 'Zone People Occupant Count(Bedroom)': 0.0, 'Zone Thermostat Heating Setpoint Temperature(Living)': 21.05137950854074, 'Zone Thermostat Heating Setpoint Temperature(Bedroom)': 17.06733172681708, 'Zone Ventilation Air Change Rate(Living)': 0.6979008846699909, 'Zone Ventilation Air Change Rate(Bedroom)': 0.3956105223095461, 'Schedule Value(Grid Carbon Intensity Schedule)': 75.83333333333334}

# %%
len(no_outdoor_obs_dict)
# Out:
# 24

# %%
baseline_obs_dict = {'year': 2022, 'month': 1, 'day': 19, 'hour': 17, 'Site Outdoor Air Drybulb Temperature(Environment)': 6.635, 'Site Outdoor Air Relative Humidity(Environment)': 75.33333333333333, 'Site Wind Speed(Environment)': 3.628333333333333, 'Site Wind Direction(Environment)': 314.1666666666667, 'Site Diffuse Solar Radiation Rate per Area(Environment)': 0.0, 'Site Direct Solar Radiation Rate per Area(Environment)': 0.0, 'Site Rain Status(Environment)': 0.0, 'Environmental Impact Total CO2 Emissions Carbon Equivalent Mass(Site)': 0.1416990439996645, 'Facility Total Electricity Demand Rate(Whole Building)': 0.0, 'Zone Air Temperature(Living)': 20.00701955490397, 'Zone Air Temperature(Bedroom)': 19.39220166949009, 'Zone Air Temperature(Subfloor)': 9.468555256616298, 'Zone Air Relative Humidity(Living)': 32.52547076451952, 'Zone Air Relative Humidity(Bedroom)': 33.86237767766038, 'Zone Air Relative Humidity(Subfloor)': 63.91147131734434, 'Zone Air CO2 Concentration(Living)': 422.5842951914865, 'Zone Air CO2 Concentration(Bedroom)': 420.0007022448027, 'Zone Air CO2 Concentration(Subfloor)': 420.0000000000009, 'Zone People Occupant Count(Living)': 0.0, 'Zone People Occupant Count(Bedroom)': 0.0, 'Zone Thermostat Heating Setpoint Temperature(Living)': 20.05191847029199, 'Zone Thermostat Heating Setpoint Temperature(Bedroom)': 19.35261564763783, 'Zone Ventilation Air Change Rate(Living)': 1.861505292382397, 'Zone Ventilation Air Change Rate(Bedroom)': 0.7473597142206623, 'Schedule Value(Grid Carbon Intensity Schedule)': 191.1666666666667, 'Schedule Value(1 Hour Temperature Forecast Schedule)': 4.899999999999999, 'Schedule Value(1 Hour Grid Carbon Forecast Schedule)': 195.83}

# %%
no_outdoor_obs_dict = {'year': 2022, 'month': 3, 'day': 8, 'hour': 23, 'Environmental Impact Total CO2 Emissions Carbon Equivalent Mass(Site)': 0.05685520055812155, 'Facility Total Electricity Demand Rate(Whole Building)': 0.0, 'Zone Air Temperature(Living)': 18.87593491790602, 'Zone Air Temperature(Bedroom)': 21.75096762801047, 'Zone Air Temperature(Subfloor)': 11.70156036808138, 'Zone Air Relative Humidity(Living)': 28.7659215879625, 'Zone Air Relative Humidity(Bedroom)': 24.1407259413058, 'Zone Air Relative Humidity(Subfloor)': 45.15618307119228, 'Zone Air CO2 Concentration(Living)': 431.913213434762, 'Zone Air CO2 Concentration(Bedroom)': 517.1891038394629, 'Zone Air CO2 Concentration(Subfloor)': 420.0000000000002, 'Zone People Occupant Count(Living)': 0.0, 'Zone People Occupant Count(Bedroom)': 2.0, 'Zone Thermostat Heating Setpoint Temperature(Living)': 16.67803230954354, 'Zone Thermostat Heating Setpoint Temperature(Bedroom)': 21.74811979014611, 'Zone Ventilation Air Change Rate(Living)': 0.2149522170880017, 'Zone Ventilation Air Change Rate(Bedroom)': 0.2668857560299615, 'Schedule Value(Grid Carbon Intensity Schedule)': 103.5, 'Schedule Value(1 Hour Temperature Forecast Schedule)': 5.97, 'Schedule Value(1 Hour Grid Carbon Forecast Schedule)': 95.5}

# %%
from cubes.construct.buildingconfig import load_building_config
from cubes.construct.building import Building
from cubes.package.utilities import get_rdd_file
from cubes.package.envconfig import EnvConfig
from cubes.package.simple_simulation import prepare_simulation
import os
import pandas as pd
from geomeppy import IDF
import pathlib as Path

#materials = pd.read_pickle('/workspaces/CUBES/cubes/materials.pickle')
#windows = pd.read_pickle('/workspaces/CUBES/cubes/windows.pickle')

files_dir = os.getcwd()

bc_file_path = "/workspaces/CUBES/exp/hannes/Leiden-study/01_evaluate_input/evaluation_new/case_0/year_2022/rep_0/input_c.json"#'input_c.json'

BC = load_building_config(bc_file_path)
EC = EnvConfig(files_dir=files_dir)
building=Building(BC,materials,windows)
building.build()

idf = building.get_idf()
idf.save("dummy.idf")

#idf, epw = prepare_simulation(idf, BC, EC)
# Out:
# <jemalloc>: MADV_DONTNEED does not work (memset will be used instead)
# <jemalloc>: (This is the expected behaviour if you are running under QEMU)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /workspaces/CUBES/exp/jack/training_tests/test.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> from geomeppy import IDF
#       <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> import pathlib as Path
# ---> <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> materials = pd.read_pickle('/workspaces/CUBES/cubes/materials.pickle')
#      <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> windows = pd.read_pickle('/workspaces/CUBES/cubes/windows.pickle')
#      <a href='vscode-notebook-cell://dev-container%..._tests/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> files_dir = os.getcwd()
#
# File /usr/local/lib/python3.9/dist-packages/pandas/io/pickle.py:190, in read_pickle(filepath_or_buffer, compression, storage_options)
#     124 """
#     125 Load pickled pandas object (or any object) from file.
#     126
#    (...)
#     187 4    4    9
#     188 """
#     189 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 190 with get_handle(
#     191     filepath_or_buffer,
#     192     "rb",
#     193     compression=compression,
#     194     is_text=False,
#     195     storage_options=storage_options,
#     196 ) as handles:
#     197
#     198     # 1) try standard library Pickle
#     199     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     200     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     202     try:
#     203         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     204         try:
#
# File /usr/local/lib/python3.9/dist-packages/pandas/io/common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/CUBES/cubes/materials.pickle'

# %%
idf.view_model()

# %%
idf.rotate(90)
idf.view_model()

# %%
idf.rotate(90)
idf.view_model()

# %%
idf.to_obj('mymodel.obj')
