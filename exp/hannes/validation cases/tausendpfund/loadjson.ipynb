# %%
from cubes.construct.buildingconfig import load_building_config

BC = load_building_config("test.json")
# Out:
# ---------------------------------------------------------------------------
# WrongTypeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from cubes.construct.buildingconfig import load_building_config
# ----> 3 load_building_config("test.json")
#
# File /workspaces/elizabeth-homes/src/cubes/construct/buildingconfig.py:101, in load_building_config(path_to_datafile)
#      99 file = open(path_to_datafile, encoding="utf-8")
#     100 data = json.loads(file.read())
# --> 101 return from_dict(data_class=BuildingConfig, data=data)
#
# File /usr/local/lib/python3.9/dist-packages/dacite/core.py:74, in from_dict(data_class, data, config)
#      72         raise
#      73     if config.check_types and not is_instance(value, field.type):
# ---> 74         raise WrongTypeError(field_path=field.name, field_type=field.type, value=value)
#      75 else:
#      76     try:
#
# ...
