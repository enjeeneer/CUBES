# %%
import pandas as pd
progress = pd.read_csv('Eplus-env-test_env-v1-res21/progress.csv')

# %%
progress = progress.dropna()
progress
# Out:
#     episode_num  cumulative_reward  mean_reward  cumulative_emissions  \
# 0             0      -88103.436707    -1.676245           1686.804763
# 1             1      -82956.970977    -1.578329           1511.087472
# 3             3      -85268.203166    -1.622302           1453.317058
# 4             4      -85268.203166    -1.622302           1453.317058
# 5             5      -82423.190731    -1.568173           1468.842572
# 6             6      -81795.273670    -1.556227           1403.815085
# 8             8      -85466.961114    -1.626084           1336.910149
# 9             9      -85466.961114    -1.626084           1336.910149
# 10           10      -82220.046970    -1.564308           1393.506264
# 11           11      -81994.628529    -1.560020           1381.028198
# 13           13      -87625.058473    -1.667143           1308.984517
# 14           14      -87625.058473    -1.667143           1308.984517
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(progress["mean_reward"],label="mean reward")
plt.plot(progress["mean_emissions_penalty"]/3,label="mean emissions reward")
plt.plot(progress["mean_comfort_penalty"]/3,label="mean comfort reward")
plt.plot(progress["mean_air_quality_penalty"]/3,label="mean air quality reward")
plt.xlabel("episodes")
