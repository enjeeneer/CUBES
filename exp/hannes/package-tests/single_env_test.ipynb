# %%
import gym
import numpy as np
import sys

#add elhogym to the PYTHONPATH
#sys.path.insert(0, '/workspaces/elizabeth-homes/exp/hannes')
#load environment definition from input folder
#import input
#make environment
#env = gym.make('Eplus-1storeytest-v2')

from cubes.package.core import make_test_env
make_test_env()
# Out:
# Warning: Gym version v0.24.1 has a number of critical issues with `gym.make` such that environment observation and action spaces are incorrectly evaluated, raising incorrect errors and warning . It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# /usr/local/lib/python3.9/dist-packages/geomeppy/geom/polygons.py:2: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import MutableSequence
# /workspaces/elizabeth-homes/src/cubes/construct/building.py:131: RuntimeWarning: invalid value encountered in sqrt
#   + np.sqrt(
# /workspaces/elizabeth-homes/src/cubes/construct/building.py:141: RuntimeWarning: invalid value encountered in sqrt
#   - np.sqrt(
# /usr/local/lib/python3.9/dist-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [1], line 13
#       5 #add elhogym to the PYTHONPATH
#       6 #sys.path.insert(0, '/workspaces/elizabeth-homes/exp/hannes')
#       7 #load environment definition from input folder
#       8 #import input
#       9 #make environment
#      10 #env = gym.make('Eplus-1storeytest-v2')
#      12 from cubes.package.core import make_test_env
# ---> 13 make_test_env()
#
# File /workspaces/elizabeth-homes/src/cubes/package/core.py:12, in make_test_env()
#      10 def make_test_env():
#      11     # get idf file
# ---> 12     idf_file = sample_idf()
#      14     # get rdd file
#      15     # rdd_file = utilities.get_rdd_file(idf_file)
#      16
#      17     # save it somewhere
#      19     cwd_path = os.getcwd()
#
# File /workspaces/elizabeth-homes/src/cubes/construct/core.py:13, in sample_idf()
#       9 geometry_data, systems_data = sample.sample_database(
#      10     constants.filtered_geometry_data, constants.clean_system_data
#      11 )
#      12 build = building.Building(geometry_data, systems_data)
# ---> 13 build.build()
#      14 idf = build.get_idf()
#      16 return idf
#
# File /workspaces/elizabeth-homes/src/cubes/construct/building.py:500, in Building.build(self)
#     498 """Creates the building"""
#     499 # May want to change the block name - again nomenclature
# --> 500 self.idf.add_block(
#     501     name="Living",
#     502     coordinates=[
#     503         (self.l_wall_front, 0),
#     504         (self.l_wall_front, self.l_wall_side),
#     505         (0, self.l_wall_side),
#     506         (0, 0),
#     507     ],
#     508     height=self.n_storey * self.h_ceiling,
#     509     num_stories=self.n_storey,
#     510 )
#     512 # self.idf.set_default_constructions()
#     514 if self.r_floor_roof != 1:
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/idf.py:292, in IDF.add_block(self, *args, **kwargs)
#     289     raise ValueError("%s is not a valid zoning rule" % block.zoning)
#     291 for zone in zones:
# --> 292     self.add_zone(zone)
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/idf.py:349, in IDF.add_zone(self, zone)
#     340 name = "{name} {s_type} {num:04d}".format(
#     341     name=zone.name, s_type=surface_type[:-1].title(), num=i
#     342 )
#     343 s = self.newidfobject(
#     344     "BUILDINGSURFACE:DETAILED",
#     345     Name=name,
#     346     Surface_Type=surface_type[:-1],
#     347     Zone_Name=zone.name,
#     348 )
# --> 349 s.setcoords(surface_coords, ggr)
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/patches.py:61, in EpBunch.setcoords(self, poly, ggr)
#      50 surfaces = [
#      51     "BUILDINGSURFACE:DETAILED",
#      52     "WALL:DETAILED",
#    (...)
#      58     "SHADING:ZONE:DETAILED",
#      59 ]
#      60 if self.key.upper() in surfaces:
# ---> 61     set_coords(self, poly, ggr)
#      62 else:
#      63     raise AttributeError
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/geom/surfaces.py:36, in set_coords(surface, coords, ggr)
#      34 deduped = [c for i, c in enumerate(coords) if c != coords[(i + 1) % len(coords)]]
#      35 poly = Polygon3D(deduped)
# ---> 36 poly = poly.normalize_coords(ggr)
#      37 coords = [i for vertex in poly for i in vertex]
#      38 if len(coords) > 120:
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/geom/polygons.py:422, in Polygon3D.normalize_coords(self, ggr)
#     420     entry_direction = "counterclockwise"
#     421 outside_point = self.outside_point(entry_direction)
# --> 422 return normalize_coords(self, outside_point, ggr)
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/geom/polygons.py:588, in normalize_coords(poly, outside_pt, ggr)
#     586 poly = set_entry_direction(poly, outside_pt, ggr)
#     587 # check and set starting position
# --> 588 poly = set_starting_position(poly, ggr)
#     590 return poly
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/geom/polygons.py:621, in set_starting_position(poly, ggr)
#     619 else:
#     620     starting_position = ggr.Starting_Vertex_Position.lower()
# --> 621 poly = poly.order_points(starting_position)
#     623 return poly
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/geom/polygons.py:388, in Polygon3D.order_points(self, starting_position)
#     386 else:
#     387     raise ValueError("%s is not a valid starting position" % starting_position)
# --> 388 start_index = self.index(bbox_corner.closest(self))
#     389 new_vertices = [self[(start_index + i) % len(self)] for i in range(len(self))]
#     391 return Polygon3D(new_vertices)
#
# File /usr/lib/python3.9/_collections_abc.py:1016, in Sequence.index(self, value, start, stop)
#    1014 try:
#    1015     v = self[i]
# -> 1016     if v is value or v == value:
#    1017         return i
#    1018 except IndexError:
#
# File /usr/local/lib/python3.9/dist-packages/geomeppy/geom/vectors.py:35, in Vector2D.__eq__(self, other)
#      34 def __eq__(self, other):
# ---> 35     for a, b in zip(self, other):
#      36         if a != b:
#      37             return False
#
# TypeError: 'NoneType' object is not iterable
