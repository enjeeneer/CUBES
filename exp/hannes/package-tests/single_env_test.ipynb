# %%
from cubes.package.core import make_test_env
import gym
env_id = make_test_env()
print(env_id)
env = gym.make(env_id)
# Out:
# EnergyPlus Completed Successfully.
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:112: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.9/dist-packages/gym/envs/registration.py:517: UserWarning: WARN: Overriding environment cubesgym-test-v1
#   logger.warn(f"Overriding environment {spec.id}")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 4
#       2 import gym
#       3 env_id = make_test_env()
# ----> 4 env = gym.make(env_id)
#
# File /usr/local/lib/python3.9/dist-packages/gym/envs/registration.py:546, in make(id, max_episode_steps, autoreset, disable_env_checker, **kwargs)
#     544     spec_ = id
#     545 else:
# --> 546     module, id = (None, id) if ":" not in id else id.split(":")
#     547     if module is not None:
#     548         try:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
for i in range(1):
    obs = env.reset()
    rewards = []
    done = False
    current_month = 0
    while not done:
        a = env.action_space.sample()
        obs, reward, done, info = env.step(a)
        rewards.append(reward)
        if info['month'] != current_month:  # display results every month
            current_month = info['month']
            print('Reward: ', sum(rewards), info)
