# %%
#import gym
#import numpy as np
#import sys

#add elhogym to the PYTHONPATH
#sys.path.insert(0, '/workspaces/elizabeth-homes/exp/hannes')
#load environment definition from input folder
#import input
#make environment
#env = gym.make('Eplus-1storeytest-v2')

from cubes.package.core import make_test_env
make_test_env()

# %%
# Out:
# /usr/local/EnergyPlus-9-5-0/energyplus --weather /workspaces/elizabeth-homes/src/cubes/data/weather/cambridge_lat=52.25_lng=0.25_period=2021.epw --output-directory /workspaces/elizabeth-homes/exp/hannes/package-tests/exp/hannes/construct-tests/test1 --idd /usr/local/EnergyPlus-9-5-0/Energy+.idd --expandobjects /workspaces/elizabeth-homes/exp/hannes/package-tests/in.idf
#
# ERROR: /workspaces/elizabeth-homes/exp/hannes/package-tests/exp/hannes/construct-tests/ is not a directory.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/eppy/runner/run_functions.py:374, in run(idf, weather, output_directory, annual, design_day, idd, epmacro, expandobjects, readvars, output_prefix, output_suffix, version, verbose, ep_version)
#     373     print("\r\n" + " ".join(cmd) + "\r\n")
# --> 374     check_call(cmd)
#     375 elif verbose == "q":
#
# File /usr/lib/python3.9/subprocess.py:373, in check_call(*popenargs, **kwargs)
#     372         cmd = popenargs[0]
# --> 373     raise CalledProcessError(retcode, cmd)
#     374 return 0
#
# CalledProcessError: Command '['/usr/local/EnergyPlus-9-5-0/energyplus', '--weather', '/workspaces/elizabeth-homes/src/cubes/data/weather/cambridge_lat=52.25_lng=0.25_period=2021.epw', '--output-directory', '/workspaces/elizabeth-homes/exp/hannes/package-tests/exp/hannes/construct-tests/test1', '--idd', '/usr/local/EnergyPlus-9-5-0/Energy+.idd', '--expandobjects', '/workspaces/elizabeth-homes/exp/hannes/package-tests/in.idf']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# EnergyPlusRunError                        Traceback (most recent call last)
# Cell In [2], line 2
#       1 from cubes.construct.core import test_idf
# ----> 2 test_idf()
#
# File /workspaces/elizabeth-homes/src/cubes/construct/core.py:25, in test_idf()
#      21 idf1 = sample_idf()
#      22 idf1.save(
#      23     filename="/workspaces/elizabeth-homes/exp/hannes/construct-tests/test1.idf"
#      24 )
# ---> 25 idf1.run(
#      26     expandobjects=True,
#      27     weather=(
#      28         "/workspaces/elizabeth-homes/src/cubes/data/"
#      29         "weather/cambridge_lat=52.25_lng=0.25_period=2021.epw"
#      30     ),
#      31     output_directory="exp/hannes/construct-tests/test1/",
#      32 )
#
# File /usr/local/lib/python3.9/dist-packages/eppy/modeleditor.py:1063, in IDF.run(self, **kwargs)
#    1061 epw = kwargs.pop("weather", self.epw)
#    1062 try:
# -> 1063     run(self, weather=epw, idd=idd, **kwargs)
#    1064 finally:
#    1065     os.remove("in.idf")
#
# File /usr/local/lib/python3.9/dist-packages/eppy/runner/run_functions.py:389, in run(idf, weather, output_directory, annual, design_day, idd, epmacro, expandobjects, readvars, output_prefix, output_suffix, version, verbose, ep_version)
#     387         err_file = os.path.join(output_dir, "eplusout.err")
#     388     message = parse_error(tmp_err, err_file)
# --> 389     raise EnergyPlusRunError(message)
#     390 finally:
#     391     sys.stderr = old_err
#
# EnergyPlusRunError:
#
# Contents of EnergyPlus error file at /workspaces/elizabeth-homes/exp/hannes/package-tests/exp/hannes/construct-tests/test1/eplusout.err
# <File not found>
