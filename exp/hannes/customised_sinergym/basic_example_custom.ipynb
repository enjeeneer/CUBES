# %% [markdown]
# # Basic example

# %% [markdown]
# Sinergym uses the standard OpenAI gym API. Lets see how to create a basic loop.
#
# First we need to include sinergym and create an environment, in our case using 'Eplus-demo-v1'

# %%
import gym
import numpy as np
import sinergym
import case_def
env = gym.make('Eplus-1storeytest-v1')
# Out:
# /workspaces/elizabeth-homes/exp/hannes/customised_sinergym/data
# /workspaces/elizabeth-homes/exp/hannes/customised_sinergym/data/variables/1_storey_test.rdd
# no file found at given path, content will be considered as empty (GBR_ENG_London.Wea.Ctr-St.James.Park.037700_TMYx.2004-2018.rain)
# [2022-08-26 15:06:49,193] EPLUS_ENV_1storeytest-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2022-08-26 15:06:49,193] EPLUS_ENV_1storeytest-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /workspaces/elizabeth-homes/exp/hannes/customised_sinergym/basic_example_custom.ipynb Cell 3 in <cell line: 7>()
#       <a href='vscode-notebook-cell://dev-container%2B2f686f6d652f68616e6e65732f656c697a61626574682d686f6d6573/workspaces/elizabeth-homes/exp/hannes/customised_sinergym/basic_example_custom.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> import constants
#       <a href='vscode-notebook-cell://dev-container%2B2f686f6d652f68616e6e65732f656c697a61626574682d686f6d6573/workspaces/elizabeth-homes/exp/hannes/customised_sinergym/basic_example_custom.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> print(constants.PKG_DATA_PATH)
# ----> <a href='vscode-notebook-cell://dev-container%2B2f686f6d652f68616e6e65732f656c697a61626574682d686f6d6573/workspaces/elizabeth-homes/exp/hannes/customised_sinergym/basic_example_custom.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> env = gym.make('Eplus-1storeytest-v1')
#
# File /usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:235, in make(id, **kwargs)
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:129, in EnvRegistry.make(self, path, **kwargs)
#     127     logger.info("Making new env: %s", path)
#     128 spec = self.spec(path)
# --> 129 env = spec.make(**kwargs)
#     130 return env
#
# File /usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:90, in EnvSpec.make(self, **kwargs)
#      88 else:
#      89     cls = load(self.entry_point)
# ---> 90     env = cls(**_kwargs)
#      92 # Make the environment aware of which spec it came from.
#      93 spec = copy.deepcopy(self)
#
# File /workspaces/elizabeth-homes/exp/hannes/customised_sinergym/eplus_env_custom.py:84, in EplusEnvCustom.__init__(self, idf_file, weather_file, observation_space, observation_variables, action_space, action_variables, action_mapping, weather_variability, reward, reward_kwargs, act_repeat, max_ep_data_store_num, env_name, config_params)
#      79 self.variables["action"] = action_variables
#      81 # ---------------------------------------------------------------------------- #
#      82 #                                   Simulator                                  #
#      83 # ---------------------------------------------------------------------------- #
# ---> 84 self.simulator = EnergyPlusCustom(
#      85     env_name=env_name,
#      86     eplus_path=eplus_path,
#      87     bcvtb_path=bcvtb_path,
#      88     idf_path=self.idf_path,
#      89     weather_path=self.weather_path,
#      90     variables=self.variables,
#      91     act_repeat=act_repeat,
#      92     max_ep_data_store_num=max_ep_data_store_num,
#      93     config_params=config_params,
#      94 )
#      96 # ---------------------------------------------------------------------------- #
#      97 #        Adding simulation date to observation (not needed in simulator)       #
#      98 # ---------------------------------------------------------------------------- #
#     100 self.variables["observation"] = [
#     101     "year",
#     102     "month",
#     103     "day",
#     104     "hour",
#     105 ] + self.variables["observation"]
#
# File /workspaces/elizabeth-homes/exp/hannes/customised_sinergym/custom_eplus_simulator.py:119, in EnergyPlusCustom.__init__(self, eplus_path, weather_path, bcvtb_path, idf_path, env_name, variables, act_repeat, max_ep_data_store_num, action_definition, config_params)
#     115 # Updating IDF file (Location and DesignDays) with EPW file
#     116 self.logger_main.info(
#     117     "Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file..."
#     118 )
# --> 119 self._config.adapt_idf_to_epw()
#     120 # Updating IDF file Output:Variables with observation variables
#     121 # specified in environment and variables.cfg construction
#     122 self.logger_main.info(
#     123     "Updating idf OutPut:Variable and variables XML tree model for BVCTB connection."
#     124 )
#
# File /sinergym/sinergym/utils/config.py:106, in Config.adapt_idf_to_epw(self, summerday, winterday)
#      96 def adapt_idf_to_epw(self,
#      97                      summerday: str = 'Ann Clg .4% Condns DB=>MWB',
#      98                      winterday: str = 'Ann Htg 99.6% Condns DB') -> None:
#      99     """Given a summer day name and winter day name from DDY file, this method modify IDF Location and DesingDay's in order to adapt IDF to EPW.
#     100
#     101     Args:
#     102         summerday (str): Design day for summer day specifically (DDY has several of them).
#     103         winterday (str): Design day for winter day specifically (DDY has several of them).
#     104     """
# --> 106     old_location = self.building.site_location[0]
#     107     old_designdays = self.building.SizingPeriod_DesignDay
#     109     # Adding the new location and designdays based on ddy file
#     110     # LOCATION
#
# File /usr/local/lib/python3.10/dist-packages/opyplus/epm/table.py:162, in Table.__getitem__(self, item)
#     149 def __getitem__(self, item):
#     150     """
#     151     Get record by index.
#     152
#    (...)
#     160     Record or typing.List[Record]
#     161     """
# --> 162     return self.select()[item]
#
# File /usr/local/lib/python3.10/dist-packages/opyplus/epm/queryset.py:89, in Queryset.__getitem__(self, item)
#      76 def __getitem__(self, item):
#      77     """
#      78     Get record(s) from the queryset by index/slice.
#      79
#    (...)
#      87     opyplus.epm.record.Record
#      88     """
# ---> 89     return self._records[item]
#
# IndexError: tuple index out of range

# %% [markdown]
# At first glance may appear that sinergym is only imported but never used, but by importing Sinergym all its [Environments](https://ugr-sail.github.io/sinergym/compilation/html/pages/environments.html)
# are defined to be used, in this case 'Eplus-demo-v1' with all the information contained in the idf file and the config file.
#
# After this simple definition we are ready to loop the episodes, for this simple example we are going to consider only 1 episode. In summary the code we need is something like this:

# %%
for i in range(1):
    obs = env.reset()
    rewards = []
    done = False
    current_month = 0
    while not done:
        a = env.action_space.sample()
        obs, reward, done, info = env.step(a)
        rewards.append(reward)
        if info['month'] != current_month:  # display results every month
            current_month = info['month']
            print('Reward: ', sum(rewards), info)
# Out:
# [2022-08-26 10:45:21,198] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2022-08-26 10:45:21,207] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/elizabeth-homes/exp/hannes/Eplus-env-demo-v1-res1/Eplus-env-sub_run1
# Reward:  -0.4363298936182648 {'timestep': 1, 'time_elapsed': 900, 'year': 1991, 'month': 1, 'day': 1, 'hour': 0, 'total_power': 8726.597872365295, 'total_power_no_units': -0.8726597872365296, 'comfort_penalty': -0.0, 'abs_comfort': 0.0, 'temperatures': [21.50800831597146], 'out_temperature': 1.8, 'action_': [22, 23]}
# Reward:  -1856.436810447357 {'timestep': 2976, 'time_elapsed': 2678400, 'year': 1991, 'month': 2, 'day': 1, 'hour': 0, 'total_power': 10012.97326793479, 'total_power_no_units': -1.001297326793479, 'comfort_penalty': -0.0, 'abs_comfort': 0.0, 'temperatures': [20.33446698895941], 'out_temperature': -7.0, 'action_': [22, 22]}
# Reward:  -3603.3198761719345 {'timestep': 5664, 'time_elapsed': 5097600, 'year': 1991, 'month': 3, 'day': 1, 'hour': 0, 'total_power': 4969.110495802121, 'total_power_no_units': -0.4969110495802121, 'comfort_penalty': -0.0, 'abs_comfort': 0.0, 'temperatures': [20.86126232997633], 'out_temperature': 8.1, 'action_': [21, 21]}
# Reward:  -4737.981356465946 {'timestep': 8640, 'time_elapsed': 7776000, 'year': 1991, 'month': 4, 'day': 1, 'hour': 0, 'total_power': 3321.145783542309, 'total_power_no_units': -0.3321145783542309, 'comfort_penalty': -0.0, 'abs_comfort': 0.0, 'temperatures': [21.93123369221784], 'out_temperature': 7.7, 'action_': [22, 22]}
# Reward:  -5553.902674835515 {'timestep': 11520, 'time_elapsed': 10368000, 'year': 1991, 'month': 5, 'day': 1, 'hour': 0, 'total_power': 963.7123569711624, 'total_power_no_units': -0.09637123569711625, 'comfort_penalty': -0.030091808746149695, 'abs_comfort': 0.030091808746149695, 'temperatures': [19.96990819125385], 'out_temperature': 13.0, 'action_': [20, 25]}
# Reward:  -6299.48413676186 {'timestep': 14496, 'time_elapsed': 13046400, 'year': 1991, 'month': 6, 'day': 1, 'hour': 0, 'total_power': 311.2037327100657, 'total_power_no_units': -0.03112037327100657, 'comfort_penalty': -1.8406784714535789, 'abs_comfort': 1.8406784714535789, 'temperatures': [21.15932152854642], 'out_temperature': 18.4, 'action_': [20, 25]}
# Reward:  -9304.985991600313 {'timestep': 17376, 'time_elapsed': 15638400, 'year': 1991, 'month': 7, 'day': 1, 'hour': 0, 'total_power': 215.8105427091371, 'total_power_no_units': -0.02158105427091371, 'comfort_penalty': -2.3847530450926016, 'abs_comfort': 2.3847530450926016, 'temperatures': [20.6152469549074], 'out_temperature': 17.7, 'action_': [18, 27]}
# Reward:  -12664.600190787914 {'timestep': 20352, 'time_elapsed': 18316800, 'year': 1991, 'month': 8, 'day': 1, 'hour': 0, 'total_power': 9011.094396079732, 'total_power_no_units': -0.9011094396079733, 'comfort_penalty': -1.1637750516706014, 'abs_comfort': 1.1637750516706014, 'temperatures': [21.8362249483294], 'out_temperature': 20.6, 'action_': [22, 23]}
# Reward:  -15956.80759910279 {'timestep': 23328, 'time_elapsed': 20995200, 'year': 1991, 'month': 9, 'day': 1, 'hour': 0, 'total_power': 367.8874627648617, 'total_power_no_units': -0.03678874627648617, 'comfort_penalty': -2.978146112251931, 'abs_comfort': 2.978146112251931, 'temperatures': [20.02185388774807], 'out_temperature': 18.8, 'action_': [19, 26]}
# Reward:  -18782.82191493832 {'timestep': 26208, 'time_elapsed': 23587200, 'year': 1991, 'month': 10, 'day': 1, 'hour': 0, 'total_power': 186.5934720667916, 'total_power_no_units': -0.018659347206679163, 'comfort_penalty': -0.0, 'abs_comfort': 0.0, 'temperatures': [20.31836168144539], 'out_temperature': 13.3, 'action_': [18, 27]}
# Reward:  -19679.15709808425 {'timestep': 29184, 'time_elapsed': 26265600, 'year': 1991, 'month': 11, 'day': 1, 'hour': 0, 'total_power': 186.5934720667916, 'total_power_no_units': -0.018659347206679163, 'comfort_penalty': -0.18892096771120848, 'abs_comfort': 0.18892096771120848, 'temperatures': [19.81107903228879], 'out_temperature': 13.0, 'action_': [17, 28]}
# Reward:  -20743.577746209106 {'timestep': 32064, 'time_elapsed': 28857600, 'year': 1991, 'month': 12, 'day': 1, 'hour': 0, 'total_power': 774.7309865008699, 'total_power_no_units': -0.07747309865008699, 'comfort_penalty': -1.36248181709853, 'abs_comfort': 1.36248181709853, 'temperatures': [18.63751818290147], 'out_temperature': 5.1, 'action_': [15, 30]}
# Reward:  -22504.157174249314 {'timestep': 35040, 'time_elapsed': 31536000, 'year': 1992, 'month': 1, 'day': 1, 'hour': 0, 'total_power': 7585.018539083838, 'total_power_no_units': -0.7585018539083839, 'comfort_penalty': -2.1851945038651586, 'abs_comfort': 2.1851945038651586, 'temperatures': [17.81480549613484], 'out_temperature': -12.0, 'action_': [16, 29]}

# %% [markdown]
# And as always don't forget to close the environment:

# %%
env.close()
# Out:
# [2022-08-24 08:53:06,644] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.

# %% [markdown]
# Now we can see the final rewards:

# %%
print(
    'Mean reward: ',
    np.mean(rewards),
    'Cumulative reward: ',
    sum(rewards))
# Out:
# Mean reward:  -0.6440246737491857 Cumulative reward:  -22566.62456817261

# %% [markdown]
# The [list of environments](https://github.com/ugr-sail/sinergym/blob/main/sinergym/__init__.py) that we have registered in Sinergym is extensive and we use buildings changing particularities. For example, continuous action space or discrete, noise over weather, runperiod, timesteps, reward function, etc. We will see it in the following notebooks.****
