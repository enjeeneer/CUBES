# %%
from cubes.construct import constants,material

mats = [
        "Paton_cast_concrete",
        "AIR-GAP",
        "Paton_timber_floor",
        "Paton_carpet"
    ]
thicks = [
        0.4,
        0.1,
        0.02,
        0.01
    ]

constr = material.Construction(
            "Wall",
            [constants.MATERIALS[x] for x in mats],
            thicks,
        )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from cubes.construct import constants,material
#       3 mats = [
#       4         "Paton_cast_concrete",
#       5         "AIR-GAP",
#       6         "Paton_timber_floor",
#       7         "Paton_carpet"
#       8     ]
#       9 thicks = [
#      10         0.4,
#      11         0.1,
#      12         0.02,
#      13         0.01
#      14     ]
#
# ImportError: cannot import name 'constants' from 'cubes.construct' (/workspaces/CUBES/cubes/construct/__init__.py)
